# %%
import pandas as pd

# %%
df=pd.read_csv('data/oa_locations.csv')

# %%
df=pd.read_csv('data/oa_status_by_doi.csv')

# %%
df1=df.head(1000000)

# %%
df1
# Out:
#                                                       doi is_best  \
# 0                             10.1016/j.reval.2012.02.143       t
# 1                                       10.3926/jiem.1275       t
# 2                                       10.3926/jiem.1275       f
# 3                                       10.3926/jiem.1275       f
# 4                                       10.3926/jiem.1275       f
# 5                               10.1186/s12971-017-0125-z       t
# 6                               10.1186/s12971-017-0125-z       f
# 7                               10.3109/10550499409117240       t
# 8                               10.3109/10550499409117240       f
# 9                          10.1016/j.chemphys.2014.05.015       t
# 10                         10.1088/1757-899x/104/1/012011       t
# 11                             10.1016/j.ajoc.2017.06.012       t
# 12                              10.1016/j.cub.2012.08.021       t
# ...

# %%
df1.groupby('evidence').count()
# Out:
#                                                        doi  is_best     url  \
# evidence
# hybrid                                                  19       19      19
# hybrid (via cc license)                                130      130     130
# hybrid (via crossref license)                        57883    57883   57883
# hybrid (via free pdf)                                18921    18921   18921
# hybrid (via page says Open Access)                     455      455     455
# hybrid (via page says license)                        4964     4964    4964
# oa journal (via journal title in doaj)              105634   105634  105634
# oa journal (via publisher name)                     126914   126914  126914
# oa repository (via BASE doi match)                     156      156     156
# oa repository (via BASE title and first author ...     318      318     318
# oa repository (via BASE title and last author m...       1        1       1
# ...
